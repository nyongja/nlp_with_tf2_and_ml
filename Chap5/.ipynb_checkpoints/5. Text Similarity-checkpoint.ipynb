# %% [markdown]
# # 05. 텍스트 유사도
# **텍스트 유사도 문제** : 두 문장(글)이 있으 ㄹ때 두 문장 간의 유사도를 측정할 수 있는 모델을 만드는 것.
#
# kaggle의 대회 중 하나를 해결해보자.
# "Quora Questions Pairs"라는 문제로, 쿼라(Quora)는 질문을 하고 다른 사용자들로부터 답변을 받을 수 있는 서비스.
# 여러 질문들 중에서 어떤 질문이 서로 유사한지 판단하는 모델을 만든느 것이 이번 장의 목표.
#
# ## 1. 문제 소개
# - 데이터 출처
# `https://www.kaggle.com/c/quora-question-pairs/data`
#
# 쿼라 입장에서 중복된 질문들을 잘 찾기만 하면 이미 잘 작성된 답변들을 사용자들이 참고하게 할 수 있고, 더 좋은 서비스를 제공할 수 있음!
# 참고로 쿼라에서는 현재 이미 중복에 대한 검사를 하고 있고, 앞서 배운 랜덤 포레스트 모델을 통해 중복 질문들을 찾고 있음.
#
# ## 2. 데이터 분석과 전처리
# 데이터 분석을 통해 데이터의 특징을 파악하고 이를 바탕으로 데이터 전처리 작업을 진행.
# 주로 문장의 길이와 어휘 빈도 분석을 해서 그 결과를 전처리에 적용하고자 함.
# 데이터를 내려받는 것부터 시작해서 데이터를 분석한 후 전처리하는 순서로 진행.
#
# ### 데이터 불러오기와 분석하기
#
# `kaggle competitions download -c quora-question-pairs`

# %% [markdown]
# 데이터 종류
# - sample_submission.csv.zip : 우리가 만들 모델을 통해 평가 데이터에 대한 예측 결과를 캐글 홈페이지에 제출할 때 양식을 맞추기 위해 보여주는 예시 파일
# - test.csv.zip : 평가 데이터
# - train.csv.zip : 테스트 데이터

# %%
import zipfile

DATA_IN_PATH = './data_in/'
file_list = ['train.csv.zip', 'test.csv.zip', 'sample_submission.csv.zip']

for file in file_list : 
    zipRef = zipfile.ZipFile(DATA_IN_PATH + file, 'r')
    zipRef.extractall(DATA_IN_PATH)
    zipRef.close()

# %% [markdown]
# 본격적으로 데이터를 불러온 후 데이터 분석을 해보자.

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# 학습 데이터를 불러와 어떤 형태로 데이터가 구성돼 있는지 확인해 보자.

# %%
train_data = pd.read_csv(DATA_IN_PATH + 'train.csv')
train_data.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0

# %% [markdown]
# - id ; 각 행 데이터의 고유한 인덱스 값
# - qid1, qid2 : 각 질문의 고유한 인덱스
# - question1, question2 : 각 질문의 내용
# - is_duplicat : 0이면 두 개의 질문이 중복이 아니고 1이면 두 개의 질문이 중복
#
# 이제 사용할 데이터가 어떤 데이터이고, 크기가 어느 정도 되는지 출력해보자.

# %%
print("파일 크기 : ")
for file in os.listdir(DATA_IN_PATH) :
    if 'csv' in file and 'zip' not in file :
        print(file.ljust(30) + str(round(os.path.getsize(DATA_IN_PATH + file)/1000000, 2)) + "MB")
# Out:
# 파일 크기 :
# sample_submission.csv         22.35MB
# test.csv                      477.59MB
# train.csv                     63.4MB

# %% [markdown]
# 파일 크기를 보면 대부분 훈련 데이터가 평가 데이터보다 큰데, 이 데이터의 경우 테스트 데이터가 훨씬 크다.
# 그 이유는 쿼라의 경우 질문에 대해 데이터의 수가 적다면 각각을 검색을 통해 중복을 찾아내는 편법을 사용할 수 있기 때문.
#
# 먼저 학습 데이터의 개수를 알아보자.

# %%
print("전체 학습 데이터의 개수 : {}".format(len(train_data)))
# Out:
# 전체 학습 데이터의 개수 : 404290

# %% [markdown]
# 전체 질문 쌍의 개수는 40만 개.
# dataframe이 행렬 구조라면 series는 인덱스를 가지고 있는 배열.
# 지금 하나의 데이터에 두 개의 지룸ㄴ이 있는 구조인데, 전체 질문(두 개의 질문)을 한번에 분석하기 위해 판다스의 시리즈를 통해 두 개의 질문을 하나로 합친다.
#
# 참고로 앞으로 진행할 분석 순서는 질문 중복 분석, 라벨 빈도 분석, 문자 분석, 단어 분석!
#
# 첫번째, 질문 중복 분석부터 시작

# %%
train_set = pd.Series(train_data['question1'].tolist() + train_data['question2'].tolist()).astype(str) # astype은 원하는 변수형으로 바꿔주는것
train_set.head()
# Out:
# 0    What is the step by step guide to invest in sh...
# 1    What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2    How can I increase the speed of my internet co...
# 3    Why am I mentally very lonely? How can I solve...
# 4    Which one dissolve in water quikly sugar, salt...
# dtype: object

# %% [markdown]
# 이제 질문들의 중복 여부를 확인해 보자.
# 넘파이를 이용해 중복을 제거한 총 질문의 수와 반복해서 나오는 질문의 수를 확인하자.

# %%
print('교육 데이터의 총 질문 수 : {}'.format(len(np.unique(train_set))))
print('반복해서 나타나는 질문의 수 : {}'.format(np.sum(train_set.value_counts() > 1)))
# Out:
# 교육 데이터의 총 질문 수 : 537361
# 반복해서 나타나는 질문의 수 : 111873

# %% [markdown]
# 중복을 제거한 유일한 질문값만 확인하기 위해 넘파이의 unique함수 사용.
# 중복되는 질문의 정확한 개수를 확인하기 위해 2개 이상의 값을 가지는 질문인 value_counts가 2 이상인 값의 개수를 모두 더함.

# %%
len(train_set)
# Out:
# 808580

# %%
train_set.value_counts()
# Out:
# What are the best ways to lose weight?                                                                                      161
# How can you look at someone's private Instagram account without following them?                                             120
# How can I lose weight quickly?                                                                                              111
# What's the easiest way to make money online?                                                                                 88
# Can you see who views your Instagram?                                                                                        79
#                                                                                                                            ...
# What was your mental hospital stay like?                                                                                      1
# Too lazy to go visit a doctor but you guys can help me in here right? my tongue is of this colour for the last 3-4 days.      1
# What does it mean to have "manly hands"?                                                                                      1
# How likely is it that the EU will break up?                                                                                   1
# I've fallen for my best friend, how do I express it?                                                                          1
# Length: 537361, dtype: int64

# %% [markdown]
# 결과를 보면 80만 개의 데이터에서 53만 개가 유니크 데이터이므로 27만개가 중복돼 있고, 27만 개의 데이터는 11만 개 데이터의 고유한 질문으로 이뤄져 있음.

# %% [markdown]
# 이제 matplotlib을 통해 시각화해 보자.
# 'question' 값들의 개수를 보여주며 x축은 중복 개수, y값은 동일한 중복 횟수를 가진 질문의 개수를 의미

# %%
plt.figure(figsize = (12, 5))

plt.hist(train_set.value_counts(), bins = 50, alpha = 0.5, color = 'r', label = 'word')

plt.yscale('log', nonposy = 'clip')

plt.title('Log-Histogram of question appearance counts')
plt.xlabel('Number of occurrences of question')
plt.ylabel('Number of questions')
# Out:
# Text(0, 0.5, 'Number of questions')

# %% [markdown]
# 중복 횟수가 1인 질문 = 유일한 질문이 가장 많고, 대부분의 질문이 중복 횟수가 50버 ㄴ이하.
# 그리고 매우 큰 빈도를 가진 질문은 이상치임.
#
# 질문의 중복 분포를 통계치로 수치화해서 다른 방향으로 확인해보자.

# %%
print('중복 최대 개수 : {}'.format(np.max(train_set.value_counts())))
print('중복 최소 개수 : {}'.format(np.min(train_set.value_counts())))
print('중복 평균 개수 : {:.2f}'.format(np.mean(train_set.value_counts())))
print('중복 표준편차 : {:.2f}'.format(np.std(train_set.value_counts())))
print('중복 중간길이 : {}'.format(np.median(train_set.value_counts())))
print('제1사분위 중복 : {}'.format(np.percentile(train_set.value_counts(), 25)))
print('제3사분위 중복 : {}'.format(np.percentile(train_set.value_counts(), 75)))
# Out:
# 중복 최대 개수 : 161
# 중복 최소 개수 : 1
# 중복 평균 개수 : 1.50
# 중복 표준편차 : 1.91
# 중복 중간길이 : 1.0
# 제1사분위 중복 : 1.0
# 제3사분위 중복 : 1.0

# %% [markdown]
# 중복 발생 횟수의 평균이 1.5라는 것으느 많은 데이터가 최소 1개 이상 중복돼 있음을 의미.
# 즉, 중복이 많다는 뜻.
# 이제 박스 플롯을 통해 중복 횟수와 관련해서 데이터를 직관적으로 이해해 보자.

# %%
plt.figure(figsize = (12, 5))
# 박스 플롯 생성
# 첫 번째 파라미터 : 여러 분포에 대한 데이터 리스트를 입력
# labels : 입력한 데이터에 대한 라벨
# showmeans : 평균값을 마크함

plt.boxplot([train_set.value_counts()], 
           labels = ['counts'],
           showmeans = True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16dc0059788>,
#   <matplotlib.lines.Line2D at 0x16dc0059708>],
#  'caps': [<matplotlib.lines.Line2D at 0x16dc005c088>,
#   <matplotlib.lines.Line2D at 0x16dc005c7c8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x16dc00779c8>],
#  'medians': [<matplotlib.lines.Line2D at 0x16dbccef688>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16dc005be88>],
#  'means': [<matplotlib.lines.Line2D at 0x16dc005dac8>]}

# %% [markdown]
# 중복 횟수의 이상치(outliers)가 너무 넓고 많이 분포해서 박스 플롯의 다른 값을 확인하기조차 어려운 데이터.
# 이번에는 워드클라우드로 어떤 단어가 많이 나오는지 확인해보자.

# %%
from wordcloud import WordCloud
cloud = WordCloud(width = 800, height = 600).generate(" ".join(train_set.astype(str)))
plt.figure(figsize = (15, 10))
plt.imshow(cloud)
plt.axis('off')
# Out:
# (-0.5, 799.5, 599.5, -0.5)

# %% [markdown]
# best, way, good, difference 등의 단어들이 질문 할 때 많이 사용된다는 것을 알 수 있음.
# 특이한 점은 'Donald Trump'가 존재하는 것.
# 이는 선거 기간 중 학습 데이터를 만들었기 때문.
#
# 이제 질문 텍스트가 아닌 데이터의 라벨인 'is_duplicate'에 대해 알아보자.
# 라벨의 경우 질문이 중복인 경우인 1 값과 중복이 아닌 0 값이 존재.
# 라벨들의 횟수에 대해 그래프를 그려보자.

# %%
fig, axe = plt.subplots(ncols = 1)
fig.set_size_inches(6, 3)
sns.countplot(train_data['is_duplicate'])

# %% [markdown]
# 중복이 아닌 데이터가 25만 개, 중복된 데이터가 15만 개.
# 이 상태로 학습한다면 중복이 아닌 데이터 25만 개에 의존도가 높아지면서 데이터가 한쪽 라벨로 편향 됨.
#
# 이러한 경우 학습이 원활하게 되지 않을 수 있으므로 최대한 라벨의 개수를 균형 있게 맞춰준 후 진행하는 것이 좋음.
# 많은 수의 데이터를 줄이거나 적은 수의 데이터를 늘린 후 학습.

# %% [markdown]
# 다음으로 텍스트 데이터의 길이를 분석해보자.
# 문자 단위로 먼저 길이를 분석한 후 단어 단위로 길이를 분석한다.

# %%
train_length = train_set.apply(len)

# %%
plt.figure(figsize = (15, 10))
plt.hist(train_length, bins = 200, range = [0, 200], facecolor = 'r', normed = True, label= 'train')
plt.title("Normalised histogram opf character count in questions", fontsize = 15)
plt.legend()
plt.xlabel('Number of characters', fontsize= 15)
plt.ylabel("Probability", fontsize = 15)
# Out:
# C:\Users\nyong\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
# Text(0, 0.5, 'Probability')

# %% [markdown]
# 데이터의 각 질문의 길이 분포는 15 ~ 150에 대부분 모여 있으며 길이가 150에서 급격하게 줄어든느 것을 볼 때 쿼라의 질문 길이 제한이 150 정도라는 것을 추정해 볼 수 있음.

# %%
print('질문 길이 최댓값 : {}'.format(np.max(train_length)))
print('질문 길이 평균값 : {:.2f}'.format(np.mean(train_length)))
print('질문 길이 표준편차 : {:.2f}'.format(np.std(train_length)))
print('질문 길이 중간값 : {}'.format(np.median(train_length)))
print('질문 길이 제1사분위 : {}'.format(np.percentile(train_length, 25)))
print('질문 길이 제3사분위 : {}'.format(np.percentile(train_length, 75)))
# Out:
# 질문 길이 최댓값 : 1169
# 질문 길이 평균값 : 59.82
# 질문 길이 표준편차 : 31.96
# 질문 길이 중간값 : 51.0
# 질문 길이 제1사분위 : 39.0
# 질문 길이 제3사분위 : 72.0

# %% [markdown]
# 우선 평균적으로 질문 길이가 60정도라는 것.
# 그리고 중간값도 겨우 51.
# 하지만 최댓값은 1169로 평균, 중간값에 비해 매우 큰 차이를 보임.
# 이런 데이터는 제외하고 학습하는 것이 좋음.
#
# 이제 데이터의 질문 길이값에 대해서도 박스 플롯 그래프를 그려서 확인해보자.

# %%
plt.figure(figsize = (12, 5))

plt.boxplot(train_length, 
           labels = ['char_counts'],
           showmeans = True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16dc9811d08>,
#   <matplotlib.lines.Line2D at 0x16dc9811fc8>],
#  'caps': [<matplotlib.lines.Line2D at 0x16dc9812a08>,
#   <matplotlib.lines.Line2D at 0x16dc9812608>],
#  'boxes': [<matplotlib.lines.Line2D at 0x16dc980d5c8>],
#  'medians': [<matplotlib.lines.Line2D at 0x16dc9817bc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16dc98183c8>],
#  'means': [<matplotlib.lines.Line2D at 0x16dc9818f88>]}

# %% [markdown]
# 분포를 보면 문자 수의 이상치 데이터가 너무 많이 분포해서 박스 플롯의 다른 값을 확인하기조차 어려운 상태.
#
# 이제 문자를 한 단위로 하는 것이 아니라 각 데이터의 단어 개수를 하나의 단위로 사용해 길이값을 분석해 보자.

# %%
train_word_counts = train_set.apply(lambda x : len(x.split(' ')))

# %%
plt.figure(figsize = (15, 10))
plt.hist(train_word_counts, bins = 50, range = [0, 50], facecolor = 'r', normed = True, label = 'train')
plt.title('Normalised histogram of word count in questions', fontsize = 15)
plt.legend()

plt.xlabel('Number of words', fontsize = 15)
plt.ylabel('Prabability', fontsize = 15)
# Out:
# C:\Users\nyong\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
# Text(0, 0.5, 'Prabability')

# %% [markdown]
# 대부분 10개 정도의 단어로 구성된 데이터가 가장 많다는 것을 확인 가능.
# 20개 이상부터는 매우 적어짐.

# %%
print('질문 단어 개수 최댓값 : {}'.format(np.max(train_word_counts)))
print('질문 단어 개수 평균값 : {:.2f}'.format(np.mean(train_word_counts)))
print('질문 단어 개수 표준편차 : {:.2f}'.format(np.std(train_word_counts)))
print('질문 단어 개수 중간값 : {}'.format(np.median(train_word_counts)))
print('질문 단어 개수 제1사분위 : {}'.format(np.percentile(train_word_counts, 25)))
print('질문 단어 개수 제3사분위 : {}'.format(np.percentile(train_word_counts, 75)))
print('질문 단어 개수 99퍼센트 : {}'.format(np.percentile(train_word_counts, 99)))
# Out:
# 질문 단어 개수 최댓값 : 237
# 질문 단어 개수 평균값 : 11.06
# 질문 단어 개수 표준편차 : 5.89
# 질문 단어 개수 중간값 : 10.0
# 질문 단어 개수 제1사분위 : 7.0
# 질문 단어 개수 제3사분위 : 13.0
# 질문 단어 개수 99퍼센트 : 31.0

# %% [markdown]
# 평균 약 11개, 중간값도 10개, 최댓값은 237개.
#
# 박스 플롯을 통해 데이터 분포를 다시 한 번 확인하자.

# %%
plt.figure(figsize = (12, 5))

plt.boxplot(train_word_counts,
           labels = ['word counts'],
           showmeans = True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16dc98e67c8>,
#   <matplotlib.lines.Line2D at 0x16dc981e348>],
#  'caps': [<matplotlib.lines.Line2D at 0x16dbccde4c8>,
#   <matplotlib.lines.Line2D at 0x16dc98c9a48>],
#  'boxes': [<matplotlib.lines.Line2D at 0x16dc98af848>],
#  'medians': [<matplotlib.lines.Line2D at 0x16dc00327c8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16dc97ede08>],
#  'means': [<matplotlib.lines.Line2D at 0x16dc002eb48>]}

# %% [markdown]
# 문자 길이에 대한 박스 플롯과 비슷한 모양.
# 쿼라 데이터의 경우 이상치가 넓고 많이 분포돼 있음을 이를 통해 확인할 수 있다.
#
# 이제 대부분 분석이 끝났다.
# 마지막으로 몇 가지 특정 경우에 대한 비율을 확인해 보자.

# %%
qmarks = np.mean(train_set.apply(lambda x : '?' in x)) # 물음표가 구두점으로 쓰임
math = np.mean(train_set.apply(lambda x : '[math]' in x)) # []
fullstop = np.mean(train_set.apply(lambda x : '.' in x)) # 마침표
capital_first = np.mean(train_set.apply(lambda x : x[0].isupper())) # 첫 번째 대문자
capitals = np.mean(train_set.apply(lambda x : max([y.isupper() for y in x ]))) # 대문자 몇 개인지
numbers = np.mean(train_set.apply(lambda x : max([y.isdigit() for y in x]))) # 숫자가 몇 개인지

print('물음표가 있는 질문 : {:.2f}%'.format(qmarks * 100))
print('수학 태그가 있는 질문 : {:.2f}%'.format(math * 100))
print('마침표가 있는 질문 : {:.2f}%'.format(fullstop * 100))
print('첫 글자가 대문자인 질문 : {:.2f}%'.format(capital_first * 100))
print('대문자가 있는 질문 : {:.2f}%'.format(capitals * 100))
print('숫자가 있는 질문 : {:.2f}%'.format(numbers * 100))
# Out:
# 물음표가 있는 질문 : 99.87%
# 수학 태그가 있는 질문 : 0.12%
# 마침표가 있는 질문 : 6.31%
# 첫 글자가 대문자인 질문 : 99.81%
# 대문자가 있는 질문 : 99.95%
# 숫자가 있는 질문 : 11.83%

# %% [markdown]
# 대문자가 첫 글자인 질문과 물음표르 동반하는 질문이 99%이상.
# 그럼 여기서 생각해볼 부분이 있음.
# 즉, 모든 질문이 보편적으로 가지고 잇는 이 특징의 유지 여부에 대해서인데, **모두가 가지고 잇는 보편적인 특징은 여기서는 제거**
#
# 질문 데이터의 중복 여부 분포, 즉 라벨의 분포가 크게 차이나서 학습에 편향을 제공하므로 좋지 않은 영향을 줄 수 있으므로 이를 전처리 과정에서 분포를 맞추고,
# 대부분의 질문에 포함된 첫 번째 대문자는 소문자로 통일.
# 물음표 같은 구두점은 삭제하는 식으로 보편적인 특성은 제거하여 필요한 부분만 학습하게 하는 이점을 얻을 수 있음.

# %% [markdown]
# ####  데이터 전처리

# %%
import pandas as pd
import numpy as np
import re
import json

from tensorflow.python.keras.preprocessing.text import Tokenizer
from tensorflow.python.keras.preprocessing.sequence import pad_sequences

# %%
DATA_IN_PATH = './data_in/'
train_data = pd.read_csv(DATA_IN_PATH + 'train.csv', encoding = 'utf-8')

# %% [markdown]
# 맨 먼저 진행할 전처리 과정은 앞서 분석 과정에서 확이냏ㅆ던 내용 중 하나인 라벨 개수의 균형을 맞추는 것.
# 앞서 분석 과정에서 확인했듯이 중복이 아닌 데이터의 개수가 더욱 많으므로 해당 데이터 개수를 줄인 후 분석 진행.
#
# 먼저 중복인 경우와 아닌 경우로 데이터를 나눈 후 중복이 아닌 개수가 비슷하도록 데이터의 일부를 다시 뽑자.
#
# 데이터프레임 객체의 **loc** 라는 기능을 활용해 데이터를 추출.
# 이 기능을 사용해 라벨이 1인 경우와 0인 경우를 분리해서 변수를 생성.

# %%
train_pos_data = train_data.loc[train_data['is_duplicate'] == 1]
train_neg_data = train_data.loc[train_data['is_duplicate'] == 0]

# %% [markdown]
# 이제 두 변수의 길이를 맞춰야 함.
# 우선 두 변수의 길이의 차이를 계산하고 샘플링하기 위해 적은 데이터(중복 질문)의 개수가 많은 데이터(중복이 아닌 질문)에 대한 비율 계산

# %%
len(train_neg_data)
# Out:
# 255027

# %%
len(train_pos_data)
# Out:
# 149263

# %%
class_difference = len(train_neg_data) - len(train_pos_data)
sample_frac = 1 - (class_difference / len(train_neg_data)) # 차이나는 것만큼을 줄여야하니까 비율 얼만큼을 줄여야하는지 계산하기 위해

train_neg_data = train_neg_data.sample(frac = sample_frac)

# %% [markdown]
# 그러면 두 데이터 간의 개수가 거의 비슷해짐

# %%
print("중복 질문 개수 : {}".format(len(train_pos_data)))
print("중복이 아닌 질문 개수 : {}".format(len(train_neg_data)))
# Out:
# 중복 질문 개수 : 149263
# 중복이 아닌 질문 개수 : 149263

# %% [markdown]
# 이제 해당 데이터를 사용하면 균형 있게 학습할 수 있음.
# 우선 라벨에 따라 나눠진 데이터를 다시 하나로 합치자.

# %%
train_data = pd.concat([train_neg_data, train_pos_data])

# %% [markdown]
# 이제 전처리를 진행해보자.
#
# 먼저 문장 문자열에 대해 진행한다.
# 우선 학습 데이터의 질문 쌍을 하나의 질문 리스트로 만들고, 정규 표현식을 사용해 물음표와 마침표 같은 구두점 및 기호를 제거하고 모든 문자를 소문자로 바꾸는 처리를 한다.
#
# 각 데이터에 있는 두 개의 질문을 각각 리스트 형태로 만든 후 각 리스트에 대해 전처리를 진행해서 두 개의 전처리된 리스트를 만들자.

# %%
FILTERS = "([~.,!?\"':;)(])" 
change_filter = re.compile(FILTERS) # 패턴 객체 만들기

questions1 = [str(s) for s in train_data['question1']]
questions2 = [str(s) for s in train_data['question2']]


filtered_questions1 = list()
filtered_questions2 = list()

for q in questions1 :
    filtered_questions1.append(re.sub(change_filter, "", q).lower())
    
for q in questions2 :
    filtered_questions2.append(re.sub(change_filter, "", q).lower())

# %% [markdown]
# 이제 정제된 텍스트 데이터를 토크나이징하고 각 단어를 인덱스로 바꾼 후, 전체 데이터의 길이를 맞추기 위해 정의한 최대 길이보다 긴 문장은 자르고 짧은 문장은 패딩 처리.
#
# 문자열 토크나이징은 앞과 동일하게 텐서플로 케라스에서 제공하는 자연어 전처리 모듈 활용.
# 이때 토크나이징 객체를 만들 때는 두 질문 텍스트를 합친 리스트에 대해 적용하고, 토크나이징은 해당 객체를 활용해 각 질문에 대해 따로 진행.
# 이러한 방법을 사용하는 이유는 두 질문에 대해 토크나이징 방식을 동일하게 진행하고, 두 질문을 하벼 전체 단어 사전을 만들기 위해서!
#
# 토크나이징 후에는 패딩 처리를 한 벡터화 진행

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(filtered_questions1 + filtered_questions2)

# %% [markdown]
# 이렇게 생성한 토크나이징 객체를 두 질문 리스트에 적용해 각 질문을 토크나이징하고 단어들을 각 단어의 인덱스로 변환하자.

# %%
questions1_sequence = tokenizer.texts_to_sequences(filtered_questions1)
questions2_sequence = tokenizer.texts_to_sequences(filtered_questions2)

# %% [markdown]
# 단어 인덱스로 이뤄진 벡터로 바꾼 값을 확인해 보면 어떤 구조로 바뀌었는지 확인할 수 있을 것.
# 이제 모델에 적용하기 위해 특정 길이로 동일하게 맞춰야 함.
# 따라서 최대 길이를 정한 후 그 길이보다 긴 질문은 자르고, 짧은 질문은 부족한 부분을 0으로 채우는 패딩 과정 진행

# %%
MAX_SEQUENCE_LENGTH = 31

# %%
q1_data = pad_sequences(questions1_sequence, maxlen = MAX_SEQUENCE_LENGTH, padding = 'post')
q2_data = pad_sequences(questions2_sequence, maxlen = MAX_SEQUENCE_LENGTH, padding = 'post')

# %% [markdown]
# 최대 길이는 앞서 데이터 분석에서 확인했던 단어 개수의 99퍼센트인 31로 설정. (이상치를 뺀 나머지를 포함하기 위해서 - 다양한 값으로 실험해본 결과 이 값이 가장 좋았음)
#
# 전처리가 끝난 데이터를 저장하자.
# 저장하기 전에 라벨값과 단어 사전을 저장하기 위해 값을 저장한 후 각 데이터의 크기를 확인해 보자.

# %%
word_vocab = {}
word_vocab = tokenizer.word_index
word_vocab["<PAD>"] = 0

labels = np.array(train_data['is_duplicate'], dtype = int)

print("Shape of question1 data : {}".format(q1_data.shape))
print("Shape of question2 data : {}".format(q2_data.shape))
print("Shape of label : {}".format(labels.shape))
print("Words in index : {}".format(len(word_vocab)))
# Out:
# Shape of question1 data : (298526, 31)
# Shape of question2 data : (298526, 31)
# Shape of label : (298526,)
# Words in index : 76416

# %% [markdown]
# 단어 사전과 전체 단어의 개수는 딕셔너리 형태로 저장해두자.

# %%
data_configs = {}
data_configs['vocab'] = word_vocab
data_configs['vocab_size'] = len(word_vocab)

# %%
TRAIN_Q1_DATA = 'q1_train.npy'
TRAIN_Q2_DATA = 'q2_train.npy'
TRAIN_LABEL_DATA = 'label_train.npy'
DATA_CONFIGS = 'data_configs.npy'

np.save(open(DATA_IN_PATH + TRAIN_Q1_DATA, 'wb'), q1_data)
np.save(open(DATA_IN_PATH + TRAIN_Q2_DATA, 'wb'), q2_data)
np.save(open(DATA_IN_PATH + TRAIN_LABEL_DATA, 'wb'), labels)

json.dump(data_configs, open(DATA_IN_PATH + DATA_CONFIGS, 'w'))

# %% [markdown]
# 넘파이의 save 함수를 활용해 각 질문과 라벨 데이터를 저장한다.
# 딕셔너리 형태의 데이터 정보는 json 파일로 저장.
# 이렇게 하면 학습할 모델에 대한 데이터 전처리가 완료된다.
#
# 전처리한 데이터는 뒤에 모델 학습을 하는 과정에서 손쉽게 활용될 것이다.
#
# 이제 평가 데이터에 대해서도 앞의 전처리 과정을 동일하게 진행한 후 전처리한 데이터를 저장하자.

# %%
test_data = pd.read_csv(DATA_IN_PATH + 'test.csv', encoding = "utf-8")
valid_ids = [type(x) == int for x in test_data.test_id]
test_data = test_data[valid_ids].drop_duplicates()

# %% [markdown]
# 평가 데이터의 길이가 학습 데이터와 비교했을 때 매우 길어 훨씬 시간이 많이 소요됨

# %%
test_questions1 = [str(s) for s in test_data['question1']]
test_questions2 = [str(s) for s in test_data['question2']]

filtered_test_questions1 = list()
filtered_test_questions2 = list()

for q in test_questions1 :
    filtered_test_questions1.append(re.sub(change_filter, "", q).lower())
    
for q in test_questions2 :
    filtered_test_questions2.append(re.sub(change_filter, "", q).lower())

# %% [markdown]
# 정확히는 평가 데이터를 인덱스 벡터로 만든 후 동일하게 패딩 처리를 하면 됨.
# 이때 사용하는 토크나이징 객체는 이전에 학습 데이터에서 사용했던 객체를 사용해야 동일한 인덱스를 가짐

# %%
test_questions1_sequence = tokenizer.texts_to_sequences(filtered_test_questions1)
test_questions2_sequence = tokenizer.texts_to_sequences(filtered_test_questions2)

# %%
test_q1_data = pad_sequences(test_questions1_sequence, maxlen = MAX_SEQUENCE_LENGTH, padding = 'post')
test_q2_data = pad_sequences(test_questions2_sequence, maxlen = MAX_SEQUENCE_LENGTH, padding = 'post')

# %% [markdown]
# 평가 데이터의 경우 라벨이 존재하지 않으므로 라벨은 저장할 필요 없음.
#
# 하지만 평가 데이터에 대한 결과를 캐글에 제출할 때 평가 데이터의 id 값이 필요함.
# 따라서 평가 데이터의 id값을 넘파이 배열로 만들자.
# 그리고 평가 데이터를 전처리한 값들의 크기를 출력해보자.

# %%
test_id = np.array(test_data['test_id'])

print('Shape of questions1 data : {}'.format(test_q1_data.shape))
print("Shape of questions2 data : {}".format(test_q2_data.shape))
print('Shape of ids : {}'.format(test_id.shape))
# Out:
# Shape of questions1 data : (2345796, 31)
# Shape of questions2 data : (2345796, 31)
# Shape of ids : (2345796,)

# %% [markdown]
# 이제 전처리한 평가 데이터를 파일로 저장하자.

# %%
TEST_Q1_DATA = 'test_q1.npy'
TEST_Q2_DATA = 'test_q2.npy'
TEST_ID_DATA = 'test_id.npy'

np.save(open(DATA_IN_PATH + TEST_Q1_DATA, 'wb'), test_q1_data)
np.save(open(DATA_IN_PATH + TEST_Q2_DATA, 'wb'), test_q2_data)
np.save(open(DATA_IN_PATH + TEST_ID_DATA, 'wb'), test_id)

# %% [markdown]
# ## 3. 모델링
# XG부스트 모델, 나머지 두개는 딥러닝 기반의 모델로서 하나는 합성곱 신경망을 활용한 모델과 맨하탄 거리르 호라용하는 LSTM 모델인 MaLSTM 모델.
#
# ### XG 부스트 텍스트 유사도 분석 모델
# 맨 먼저 사용할 모델은 앙상블 모델 중 하나인 XG 부스트 모델.
# 해당 모델을 사용해서 데이터의 주어진 두 질문 문장 사이의 유사도를 측정해서 두 질문이 중복인지 아닌지를 판단.
# 우선 XG 부스트 모델이 어떤 모델인지 먼저 알아보자.
#
# #### 모델 소개
# **XG 부스트** : eXtream Gradient Boosting의 약자로 최근 캐글 사용자에게 큰 인기를 얻고 있는 모델 중 하나.
# 앙상블의 한 방법인 부스팅(Boosting) 기법을 사용하는 방법.
#
# #### 모델 구현

# %%
import numpy as np

DATA_IN_PATH = './data_in/'

TRAIN_Q1_DATA_FILE = 'q1_train.npy'
TRAIN_Q2_DATA_FILE = 'q2_train.npy'
TRAIN_LABEL_DATA_FILE = 'label_train.npy'

# 훈련 데이터 가져오기
train_q1_data = np.load(open(DATA_IN_PATH + TRAIN_Q1_DATA_FILE, 'rb'))
train_q2_data = np.load(open(DATA_IN_PATH + TRAIN_Q2_DATA_FILE, 'rb'))
train_labels = np.load(open(DATA_IN_PATH + TRAIN_LABEL_DATA_FILE, 'rb'))

# %% [markdown]
# 현재 두 질문이 따로 구성돼 있는데 이를 하나씩 묶어 하나의 질문 쌍으로 만들자.

# %%
train_input = np.stack((train_q1_data, train_q2_data), axis = 1)

# %% [markdown]
# stack 함수를 통해 두 질문을 하나의 쌍으로 만든다.
# 예를 들어 질문[A]와 질문 [B]가 있을 때 이 질문을 하나로 묶어 [[A], [B]]로 만드는 것이다.

# %%
print(train_input.shape)
# Out:
# (298526, 2, 31)

# %% [markdown]
# 이제 학습 데이터의 일부를 모델 검증을 위한 검증 데이터로 만들어 두자

# %%
from sklearn.model_selection import train_test_split

train_input, eval_input, train_label, eval_label = train_test_split(train_input, train_labels, test_size = 0.2, random_state = 4242)

# %% [markdown]
# 모델을 구현하기 위해서 **xgboost** 라는 라이브러리를 활용할 것이다.
# 우선 해당 라이브러리가 설치돼 잇지 않다면 설치하자.
#
# `https://xgboost.readthedocs.io/en/latest/`

# %%
import xgboost as xgb

# %%
train_data = xgb.DMatrix(train_input.sum(axis = 1), label = train_label)
eval_data = xgb.DMatrix(eval_input.sum(axis = 1), label = eval_label)

# %%
data_list = [(train_data, 'train'), (eval_data, 'valid')]

# %% [markdown]
# 입력값을 xgb 라이브러리의 데이터 형식은 DMatrix 형태로 만들어야 함.
# 학습 데이터와 검증 데이터 모두 적용해서 해당 데이터 형식으로 만든다.
#
# 적용 과정에서 각 데이터에 대해 sum 함수를 사용하는데 이는 각 데이터의 두 질문을 하나의 값으로 만들어 주기 위해서임.
# 그리고 두 개의 데이터를 묶어서 하나의 리스트로 만든다.
# 이때 학습 데이터와 검증 데이터는 각 상태의 문자열과 함께 튜플 형태로 구성!
#
# 이제 모델을 생성하고 학습하는 과정을 진행해 보자.

# %%
params = {}
params['objective'] = 'binary:logistic'
params['eval_metric'] = 'rmse'

bst = xgb.train(params, train_data, num_boost_round = 1000, evals = data_list, early_stopping_rounds = 10)
# Out:
# [0]	train-rmse:0.48369	valid-rmse:0.48421
# [1]	train-rmse:0.47345	valid-rmse:0.47448
# [2]	train-rmse:0.46688	valid-rmse:0.46833
# [3]	train-rmse:0.46207	valid-rmse:0.46363
# [4]	train-rmse:0.45849	valid-rmse:0.46035
# [5]	train-rmse:0.45557	valid-rmse:0.45770
# [6]	train-rmse:0.45338	valid-rmse:0.45578
# [7]	train-rmse:0.45079	valid-rmse:0.45341
# [8]	train-rmse:0.44942	valid-rmse:0.45226
# [9]	train-rmse:0.44824	valid-rmse:0.45136
# [10]	train-rmse:0.44705	valid-rmse:0.45041
# [11]	train-rmse:0.44494	valid-rmse:0.44856
# [12]	train-rmse:0.44417	valid-rmse:0.44795
# [13]	train-rmse:0.44357	valid-rmse:0.44741
# [14]	train-rmse:0.44234	valid-rmse:0.44624
# [15]	train-rmse:0.44168	valid-rmse:0.44565
# [16]	train-rmse:0.44113	valid-rmse:0.44528
# [17]	train-rmse:0.44064	valid-rmse:0.44494
# [18]	train-rmse:0.43962	valid-rmse:0.44406
# [19]	train-rmse:0.43930	valid-rmse:0.44386
# [20]	train-rmse:0.43882	valid-rmse:0.44348
# [21]	train-rmse:0.43851	valid-rmse:0.44325
# [22]	train-rmse:0.43804	valid-rmse:0.44287
# [23]	train-rmse:0.43762	valid-rmse:0.44256
# [24]	train-rmse:0.43741	valid-rmse:0.44244
# [25]	train-rmse:0.43689	valid-rmse:0.44196
# [26]	train-rmse:0.43589	valid-rmse:0.44106
# [27]	train-rmse:0.43512	valid-rmse:0.44049
# [28]	train-rmse:0.43493	valid-rmse:0.44041
# [29]	train-rmse:0.43357	valid-rmse:0.43923
# [30]	train-rmse:0.43279	valid-rmse:0.43857
# [31]	train-rmse:0.43254	valid-rmse:0.43847
# [32]	train-rmse:0.43237	valid-rmse:0.43835
# [33]	train-rmse:0.43191	valid-rmse:0.43798
# [34]	train-rmse:0.43140	valid-rmse:0.43763
# [35]	train-rmse:0.43117	valid-rmse:0.43744
# [36]	train-rmse:0.43094	valid-rmse:0.43730
# [37]	train-rmse:0.43083	valid-rmse:0.43722
# [38]	train-rmse:0.43064	valid-rmse:0.43716
# [39]	train-rmse:0.43051	valid-rmse:0.43704
# [40]	train-rmse:0.43032	valid-rmse:0.43691
# [41]	train-rmse:0.42986	valid-rmse:0.43662
# [42]	train-rmse:0.42972	valid-rmse:0.43655
# [43]	train-rmse:0.42962	valid-rmse:0.43651
# [44]	train-rmse:0.42908	valid-rmse:0.43610
# [45]	train-rmse:0.42888	valid-rmse:0.43597
# [46]	train-rmse:0.42874	valid-rmse:0.43595
# [47]	train-rmse:0.42863	valid-rmse:0.43589
# [48]	train-rmse:0.42809	valid-rmse:0.43559
# [49]	train-rmse:0.42761	valid-rmse:0.43528
# [50]	train-rmse:0.42715	valid-rmse:0.43499
# [51]	train-rmse:0.42663	valid-rmse:0.43473
# [52]	train-rmse:0.42645	valid-rmse:0.43466
# [53]	train-rmse:0.42602	valid-rmse:0.43445
# [54]	train-rmse:0.42592	valid-rmse:0.43440
# [55]	train-rmse:0.42546	valid-rmse:0.43414
# [56]	train-rmse:0.42501	valid-rmse:0.43393
# [57]	train-rmse:0.42496	valid-rmse:0.43392
# [58]	train-rmse:0.42438	valid-rmse:0.43353
# [59]	train-rmse:0.42392	valid-rmse:0.43322
# [60]	train-rmse:0.42336	valid-rmse:0.43290
# [61]	train-rmse:0.42295	valid-rmse:0.43273
# [62]	train-rmse:0.42283	valid-rmse:0.43269
# [63]	train-rmse:0.42279	valid-rmse:0.43265
# [64]	train-rmse:0.42271	valid-rmse:0.43261
# [65]	train-rmse:0.42260	valid-rmse:0.43254
# [66]	train-rmse:0.42240	valid-rmse:0.43245
# [67]	train-rmse:0.42220	valid-rmse:0.43236
# [68]	train-rmse:0.42207	valid-rmse:0.43227
# [69]	train-rmse:0.42190	valid-rmse:0.43220
# [70]	train-rmse:0.42160	valid-rmse:0.43201
# [71]	train-rmse:0.42155	valid-rmse:0.43198
# [72]	train-rmse:0.42122	valid-rmse:0.43180
# [73]	train-rmse:0.42113	valid-rmse:0.43177
# [74]	train-rmse:0.42096	valid-rmse:0.43168
# [75]	train-rmse:0.42061	valid-rmse:0.43152
# [76]	train-rmse:0.42033	valid-rmse:0.43141
# [77]	train-rmse:0.42000	valid-rmse:0.43127
# [78]	train-rmse:0.41992	valid-rmse:0.43121
# [79]	train-rmse:0.41956	valid-rmse:0.43097
# [80]	train-rmse:0.41921	valid-rmse:0.43078
# [81]	train-rmse:0.41903	valid-rmse:0.43070
# [82]	train-rmse:0.41866	valid-rmse:0.43046
# [83]	train-rmse:0.41820	valid-rmse:0.43024
# [84]	train-rmse:0.41795	valid-rmse:0.43016
# [85]	train-rmse:0.41757	valid-rmse:0.42994
# [86]	train-rmse:0.41725	valid-rmse:0.42980
# [87]	train-rmse:0.41717	valid-rmse:0.42975
# [88]	train-rmse:0.41706	valid-rmse:0.42975
# [89]	train-rmse:0.41687	valid-rmse:0.42967
# [90]	train-rmse:0.41680	valid-rmse:0.42965
# [91]	train-rmse:0.41673	valid-rmse:0.42961
# [92]	train-rmse:0.41664	valid-rmse:0.42955
# [93]	train-rmse:0.41642	valid-rmse:0.42945
# [94]	train-rmse:0.41626	valid-rmse:0.42937
# [95]	train-rmse:0.41593	valid-rmse:0.42925
# [96]	train-rmse:0.41583	valid-rmse:0.42919
# [97]	train-rmse:0.41573	valid-rmse:0.42913
# [98]	train-rmse:0.41563	valid-rmse:0.42912
# [99]	train-rmse:0.41557	valid-rmse:0.42908
# [100]	train-rmse:0.41541	valid-rmse:0.42904
# [101]	train-rmse:0.41518	valid-rmse:0.42899
# [102]	train-rmse:0.41487	valid-rmse:0.42884
# [103]	train-rmse:0.41480	valid-rmse:0.42883
# [104]	train-rmse:0.41437	valid-rmse:0.42858
# [105]	train-rmse:0.41408	valid-rmse:0.42846
# [106]	train-rmse:0.41406	valid-rmse:0.42846
# [107]	train-rmse:0.41385	valid-rmse:0.42840
# [108]	train-rmse:0.41382	valid-rmse:0.42838
# [109]	train-rmse:0.41380	valid-rmse:0.42837
# [110]	train-rmse:0.41369	valid-rmse:0.42835
# [111]	train-rmse:0.41364	valid-rmse:0.42831
# [112]	train-rmse:0.41356	valid-rmse:0.42830
# [113]	train-rmse:0.41351	valid-rmse:0.42826
# [114]	train-rmse:0.41321	valid-rmse:0.42810
# [115]	train-rmse:0.41289	valid-rmse:0.42797
# [116]	train-rmse:0.41287	valid-rmse:0.42797
# [117]	train-rmse:0.41251	valid-rmse:0.42782
# [118]	train-rmse:0.41216	valid-rmse:0.42772
# [119]	train-rmse:0.41214	valid-rmse:0.42772
# [120]	train-rmse:0.41209	valid-rmse:0.42772
# [121]	train-rmse:0.41197	valid-rmse:0.42768
# [122]	train-rmse:0.41173	valid-rmse:0.42761
# [123]	train-rmse:0.41146	valid-rmse:0.42759
# [124]	train-rmse:0.41116	valid-rmse:0.42751
# [125]	train-rmse:0.41100	valid-rmse:0.42742
# [126]	train-rmse:0.41098	valid-rmse:0.42741
# [127]	train-rmse:0.41083	valid-rmse:0.42734
# [128]	train-rmse:0.41080	valid-rmse:0.42733
# [129]	train-rmse:0.41060	valid-rmse:0.42727
# [130]	train-rmse:0.41031	valid-rmse:0.42720
# [131]	train-rmse:0.41002	valid-rmse:0.42708
# [132]	train-rmse:0.40962	valid-rmse:0.42686
# [133]	train-rmse:0.40943	valid-rmse:0.42678
# [134]	train-rmse:0.40935	valid-rmse:0.42678
# [135]	train-rmse:0.40931	valid-rmse:0.42675
# [136]	train-rmse:0.40921	valid-rmse:0.42672
# [137]	train-rmse:0.40918	valid-rmse:0.42671
# [138]	train-rmse:0.40892	valid-rmse:0.42661
# [139]	train-rmse:0.40873	valid-rmse:0.42658
# [140]	train-rmse:0.40869	valid-rmse:0.42655
# [141]	train-rmse:0.40868	valid-rmse:0.42653
# [142]	train-rmse:0.40865	valid-rmse:0.42653
# [143]	train-rmse:0.40835	valid-rmse:0.42644
# [144]	train-rmse:0.40805	valid-rmse:0.42630
# [145]	train-rmse:0.40771	valid-rmse:0.42619
# [146]	train-rmse:0.40744	valid-rmse:0.42613
# [147]	train-rmse:0.40725	valid-rmse:0.42612
# [148]	train-rmse:0.40721	valid-rmse:0.42610
# [149]	train-rmse:0.40692	valid-rmse:0.42598
# [150]	train-rmse:0.40664	valid-rmse:0.42584
# [151]	train-rmse:0.40635	valid-rmse:0.42574
# [152]	train-rmse:0.40602	valid-rmse:0.42563
# [153]	train-rmse:0.40573	valid-rmse:0.42555
# [154]	train-rmse:0.40555	valid-rmse:0.42549
# [155]	train-rmse:0.40528	valid-rmse:0.42545
# [156]	train-rmse:0.40519	valid-rmse:0.42541
# [157]	train-rmse:0.40503	valid-rmse:0.42538
# [158]	train-rmse:0.40477	valid-rmse:0.42535
# [159]	train-rmse:0.40449	valid-rmse:0.42526
# [160]	train-rmse:0.40446	valid-rmse:0.42526
# [161]	train-rmse:0.40444	valid-rmse:0.42525
# [162]	train-rmse:0.40442	valid-rmse:0.42523
# [163]	train-rmse:0.40441	valid-rmse:0.42522
# [164]	train-rmse:0.40425	valid-rmse:0.42517
# [165]	train-rmse:0.40413	valid-rmse:0.42518
# [166]	train-rmse:0.40411	valid-rmse:0.42516
# [167]	train-rmse:0.40408	valid-rmse:0.42515
# [168]	train-rmse:0.40404	valid-rmse:0.42514
# [169]	train-rmse:0.40401	valid-rmse:0.42512
# [170]	train-rmse:0.40371	valid-rmse:0.42506
# [171]	train-rmse:0.40369	valid-rmse:0.42505
# [172]	train-rmse:0.40368	valid-rmse:0.42504
# [173]	train-rmse:0.40366	valid-rmse:0.42503
# [174]	train-rmse:0.40364	valid-rmse:0.42502
# [175]	train-rmse:0.40362	valid-rmse:0.42501
# [176]	train-rmse:0.40359	valid-rmse:0.42500
# [177]	train-rmse:0.40328	valid-rmse:0.42489
# [178]	train-rmse:0.40300	valid-rmse:0.42469
# [179]	train-rmse:0.40270	valid-rmse:0.42452
# [180]	train-rmse:0.40248	valid-rmse:0.42446
# [181]	train-rmse:0.40222	valid-rmse:0.42436
# [182]	train-rmse:0.40193	valid-rmse:0.42435
# [183]	train-rmse:0.40166	valid-rmse:0.42427
# [184]	train-rmse:0.40142	valid-rmse:0.42421
# [185]	train-rmse:0.40126	valid-rmse:0.42416
# [186]	train-rmse:0.40121	valid-rmse:0.42414
# [187]	train-rmse:0.40099	valid-rmse:0.42406
# [188]	train-rmse:0.40080	valid-rmse:0.42405
# [189]	train-rmse:0.40079	valid-rmse:0.42405
# [190]	train-rmse:0.40077	valid-rmse:0.42404
# [191]	train-rmse:0.40056	valid-rmse:0.42398
# [192]	train-rmse:0.40037	valid-rmse:0.42395
# [193]	train-rmse:0.40020	valid-rmse:0.42390
# [194]	train-rmse:0.40005	valid-rmse:0.42386
# [195]	train-rmse:0.39995	valid-rmse:0.42384
# [196]	train-rmse:0.39993	valid-rmse:0.42383
# [197]	train-rmse:0.39992	valid-rmse:0.42383
# [198]	train-rmse:0.39991	valid-rmse:0.42382
# [199]	train-rmse:0.39975	valid-rmse:0.42379
# [200]	train-rmse:0.39959	valid-rmse:0.42373
# [201]	train-rmse:0.39958	valid-rmse:0.42372
# [202]	train-rmse:0.39957	valid-rmse:0.42372
# [203]	train-rmse:0.39953	valid-rmse:0.42371
# [204]	train-rmse:0.39951	valid-rmse:0.42372
# [205]	train-rmse:0.39918	valid-rmse:0.42351
# [206]	train-rmse:0.39897	valid-rmse:0.42349
# [207]	train-rmse:0.39865	valid-rmse:0.42338
# [208]	train-rmse:0.39843	valid-rmse:0.42335
# [209]	train-rmse:0.39828	valid-rmse:0.42331
# [210]	train-rmse:0.39821	valid-rmse:0.42330
# [211]	train-rmse:0.39800	valid-rmse:0.42325
# [212]	train-rmse:0.39789	valid-rmse:0.42325
# [213]	train-rmse:0.39780	valid-rmse:0.42321
# [214]	train-rmse:0.39776	valid-rmse:0.42320
# [215]	train-rmse:0.39768	valid-rmse:0.42316
# [216]	train-rmse:0.39753	valid-rmse:0.42313
# [217]	train-rmse:0.39745	valid-rmse:0.42311
# [218]	train-rmse:0.39726	valid-rmse:0.42308
# [219]	train-rmse:0.39711	valid-rmse:0.42307
# [220]	train-rmse:0.39706	valid-rmse:0.42307
# [221]	train-rmse:0.39690	valid-rmse:0.42304
# [222]	train-rmse:0.39671	valid-rmse:0.42296
# [223]	train-rmse:0.39651	valid-rmse:0.42289
# [224]	train-rmse:0.39632	valid-rmse:0.42285
# [225]	train-rmse:0.39605	valid-rmse:0.42270
# [226]	train-rmse:0.39591	valid-rmse:0.42269
# [227]	train-rmse:0.39581	valid-rmse:0.42267
# [228]	train-rmse:0.39571	valid-rmse:0.42268
# [229]	train-rmse:0.39570	valid-rmse:0.42268
# [230]	train-rmse:0.39569	valid-rmse:0.42268
# [231]	train-rmse:0.39568	valid-rmse:0.42267
# [232]	train-rmse:0.39566	valid-rmse:0.42267
# [233]	train-rmse:0.39563	valid-rmse:0.42266
# [234]	train-rmse:0.39560	valid-rmse:0.42265
# [235]	train-rmse:0.39539	valid-rmse:0.42262
# [236]	train-rmse:0.39523	valid-rmse:0.42261
# [237]	train-rmse:0.39522	valid-rmse:0.42260
# [238]	train-rmse:0.39512	valid-rmse:0.42256
# [239]	train-rmse:0.39495	valid-rmse:0.42256
# [240]	train-rmse:0.39475	valid-rmse:0.42253
# [241]	train-rmse:0.39465	valid-rmse:0.42252
# [242]	train-rmse:0.39463	valid-rmse:0.42251
# [243]	train-rmse:0.39462	valid-rmse:0.42251
# [244]	train-rmse:0.39455	valid-rmse:0.42251
# [245]	train-rmse:0.39440	valid-rmse:0.42249
# [246]	train-rmse:0.39429	valid-rmse:0.42246
# [247]	train-rmse:0.39405	valid-rmse:0.42242
# [248]	train-rmse:0.39377	valid-rmse:0.42233
# [249]	train-rmse:0.39351	valid-rmse:0.42223
# [250]	train-rmse:0.39343	valid-rmse:0.42222
# [251]	train-rmse:0.39329	valid-rmse:0.42220
# [252]	train-rmse:0.39327	valid-rmse:0.42219
# [253]	train-rmse:0.39295	valid-rmse:0.42204
# [254]	train-rmse:0.39280	valid-rmse:0.42204
# [255]	train-rmse:0.39248	valid-rmse:0.42194
# [256]	train-rmse:0.39223	valid-rmse:0.42189
# [257]	train-rmse:0.39201	valid-rmse:0.42186
# [258]	train-rmse:0.39180	valid-rmse:0.42179
# [259]	train-rmse:0.39170	valid-rmse:0.42177
# [260]	train-rmse:0.39147	valid-rmse:0.42173
# [261]	train-rmse:0.39137	valid-rmse:0.42175
# [262]	train-rmse:0.39117	valid-rmse:0.42174
# [263]	train-rmse:0.39101	valid-rmse:0.42172
# [264]	train-rmse:0.39098	valid-rmse:0.42171
# [265]	train-rmse:0.39083	valid-rmse:0.42170
# [266]	train-rmse:0.39077	valid-rmse:0.42171
# [267]	train-rmse:0.39073	valid-rmse:0.42171
# [268]	train-rmse:0.39072	valid-rmse:0.42170
# [269]	train-rmse:0.39047	valid-rmse:0.42169
# [270]	train-rmse:0.39027	valid-rmse:0.42170
# [271]	train-rmse:0.39002	valid-rmse:0.42164
# [272]	train-rmse:0.38981	valid-rmse:0.42158
# [273]	train-rmse:0.38969	valid-rmse:0.42157
# [274]	train-rmse:0.38966	valid-rmse:0.42158
# [275]	train-rmse:0.38965	valid-rmse:0.42157
# [276]	train-rmse:0.38962	valid-rmse:0.42156
# [277]	train-rmse:0.38961	valid-rmse:0.42156
# [278]	train-rmse:0.38960	valid-rmse:0.42156
# [279]	train-rmse:0.38955	valid-rmse:0.42154
# [280]	train-rmse:0.38946	valid-rmse:0.42152
# [281]	train-rmse:0.38945	valid-rmse:0.42152
# [282]	train-rmse:0.38944	valid-rmse:0.42151
# [283]	train-rmse:0.38943	valid-rmse:0.42151
# [284]	train-rmse:0.38928	valid-rmse:0.42153
# [285]	train-rmse:0.38906	valid-rmse:0.42150
# [286]	train-rmse:0.38887	valid-rmse:0.42147
# [287]	train-rmse:0.38867	valid-rmse:0.42140
# [288]	train-rmse:0.38843	valid-rmse:0.42138
# [289]	train-rmse:0.38829	valid-rmse:0.42134
# [290]	train-rmse:0.38811	valid-rmse:0.42130
# [291]	train-rmse:0.38810	valid-rmse:0.42129
# [292]	train-rmse:0.38801	valid-rmse:0.42126
# [293]	train-rmse:0.38797	valid-rmse:0.42126
# [294]	train-rmse:0.38770	valid-rmse:0.42118
# [295]	train-rmse:0.38743	valid-rmse:0.42115
# [296]	train-rmse:0.38719	valid-rmse:0.42107
# [297]	train-rmse:0.38702	valid-rmse:0.42105
# [298]	train-rmse:0.38679	valid-rmse:0.42104
# [299]	train-rmse:0.38657	valid-rmse:0.42099
# [300]	train-rmse:0.38652	valid-rmse:0.42101
# [301]	train-rmse:0.38632	valid-rmse:0.42097
# [302]	train-rmse:0.38610	valid-rmse:0.42090
# [303]	train-rmse:0.38593	valid-rmse:0.42088
# [304]	train-rmse:0.38573	valid-rmse:0.42087
# [305]	train-rmse:0.38551	valid-rmse:0.42086
# [306]	train-rmse:0.38538	valid-rmse:0.42081
# [307]	train-rmse:0.38523	valid-rmse:0.42082
# [308]	train-rmse:0.38519	valid-rmse:0.42081
# [309]	train-rmse:0.38515	valid-rmse:0.42080
# [310]	train-rmse:0.38500	valid-rmse:0.42079
# [311]	train-rmse:0.38493	valid-rmse:0.42077
# [312]	train-rmse:0.38483	valid-rmse:0.42074
# [313]	train-rmse:0.38482	valid-rmse:0.42073
# [314]	train-rmse:0.38475	valid-rmse:0.42073
# [315]	train-rmse:0.38470	valid-rmse:0.42073
# [316]	train-rmse:0.38467	valid-rmse:0.42071
# [317]	train-rmse:0.38465	valid-rmse:0.42071
# [318]	train-rmse:0.38464	valid-rmse:0.42069
# [319]	train-rmse:0.38463	valid-rmse:0.42069
# [320]	train-rmse:0.38460	valid-rmse:0.42070
# [321]	train-rmse:0.38453	valid-rmse:0.42068
# [322]	train-rmse:0.38438	valid-rmse:0.42067
# [323]	train-rmse:0.38421	valid-rmse:0.42066
# [324]	train-rmse:0.38404	valid-rmse:0.42062
# [325]	train-rmse:0.38393	valid-rmse:0.42062
# [326]	train-rmse:0.38388	valid-rmse:0.42063
# [327]	train-rmse:0.38387	valid-rmse:0.42063
# [328]	train-rmse:0.38376	valid-rmse:0.42061
# [329]	train-rmse:0.38375	valid-rmse:0.42062
# [330]	train-rmse:0.38357	valid-rmse:0.42064
# [331]	train-rmse:0.38345	valid-rmse:0.42067
# [332]	train-rmse:0.38342	valid-rmse:0.42068
# [333]	train-rmse:0.38341	valid-rmse:0.42068
# [334]	train-rmse:0.38326	valid-rmse:0.42062
# [335]	train-rmse:0.38308	valid-rmse:0.42063
# [336]	train-rmse:0.38281	valid-rmse:0.42057
# [337]	train-rmse:0.38267	valid-rmse:0.42057
# [338]	train-rmse:0.38266	valid-rmse:0.42056
# [339]	train-rmse:0.38265	valid-rmse:0.42056
# [340]	train-rmse:0.38261	valid-rmse:0.42055
# [341]	train-rmse:0.38256	valid-rmse:0.42056
# [342]	train-rmse:0.38248	valid-rmse:0.42055
# [343]	train-rmse:0.38227	valid-rmse:0.42047
# [344]	train-rmse:0.38215	valid-rmse:0.42041
# [345]	train-rmse:0.38207	valid-rmse:0.42041
# [346]	train-rmse:0.38197	valid-rmse:0.42040
# [347]	train-rmse:0.38184	valid-rmse:0.42037
# [348]	train-rmse:0.38161	valid-rmse:0.42029
# [349]	train-rmse:0.38147	valid-rmse:0.42025
# [350]	train-rmse:0.38126	valid-rmse:0.42019
# [351]	train-rmse:0.38103	valid-rmse:0.42010
# [352]	train-rmse:0.38081	valid-rmse:0.42012
# [353]	train-rmse:0.38068	valid-rmse:0.42012
# [354]	train-rmse:0.38067	valid-rmse:0.42012
# [355]	train-rmse:0.38048	valid-rmse:0.42007
# [356]	train-rmse:0.38048	valid-rmse:0.42007
# [357]	train-rmse:0.38028	valid-rmse:0.42004
# [358]	train-rmse:0.38026	valid-rmse:0.42003
# [359]	train-rmse:0.38024	valid-rmse:0.42002
# [360]	train-rmse:0.38024	valid-rmse:0.42002
# [361]	train-rmse:0.38015	valid-rmse:0.42000
# [362]	train-rmse:0.37993	valid-rmse:0.41998
# [363]	train-rmse:0.37983	valid-rmse:0.41998
# [364]	train-rmse:0.37962	valid-rmse:0.41988
# [365]	train-rmse:0.37957	valid-rmse:0.41989
# [366]	train-rmse:0.37934	valid-rmse:0.41983
# [367]	train-rmse:0.37922	valid-rmse:0.41982
# [368]	train-rmse:0.37916	valid-rmse:0.41981
# [369]	train-rmse:0.37896	valid-rmse:0.41978
# [370]	train-rmse:0.37888	valid-rmse:0.41974
# [371]	train-rmse:0.37868	valid-rmse:0.41972
# [372]	train-rmse:0.37859	valid-rmse:0.41971
# [373]	train-rmse:0.37854	valid-rmse:0.41969
# [374]	train-rmse:0.37853	valid-rmse:0.41968
# [375]	train-rmse:0.37831	valid-rmse:0.41966
# [376]	train-rmse:0.37827	valid-rmse:0.41965
# [377]	train-rmse:0.37814	valid-rmse:0.41962
# [378]	train-rmse:0.37801	valid-rmse:0.41957
# [379]	train-rmse:0.37787	valid-rmse:0.41957
# [380]	train-rmse:0.37768	valid-rmse:0.41957
# [381]	train-rmse:0.37753	valid-rmse:0.41956
# [382]	train-rmse:0.37749	valid-rmse:0.41954
# [383]	train-rmse:0.37745	valid-rmse:0.41954
# [384]	train-rmse:0.37727	valid-rmse:0.41954
# [385]	train-rmse:0.37718	valid-rmse:0.41952
# [386]	train-rmse:0.37717	valid-rmse:0.41951
# [387]	train-rmse:0.37716	valid-rmse:0.41951
# [388]	train-rmse:0.37706	valid-rmse:0.41950
# [389]	train-rmse:0.37704	valid-rmse:0.41950
# [390]	train-rmse:0.37693	valid-rmse:0.41947
# [391]	train-rmse:0.37670	valid-rmse:0.41941
# [392]	train-rmse:0.37661	valid-rmse:0.41938
# [393]	train-rmse:0.37654	valid-rmse:0.41938
# [394]	train-rmse:0.37652	valid-rmse:0.41937
# [395]	train-rmse:0.37652	valid-rmse:0.41937
# [396]	train-rmse:0.37650	valid-rmse:0.41935
# [397]	train-rmse:0.37650	valid-rmse:0.41935
# [398]	train-rmse:0.37638	valid-rmse:0.41934
# [399]	train-rmse:0.37630	valid-rmse:0.41931
# [400]	train-rmse:0.37625	valid-rmse:0.41929
# [401]	train-rmse:0.37615	valid-rmse:0.41927
# [402]	train-rmse:0.37610	valid-rmse:0.41926
# [403]	train-rmse:0.37605	valid-rmse:0.41925
# [404]	train-rmse:0.37586	valid-rmse:0.41919
# [405]	train-rmse:0.37583	valid-rmse:0.41919
# [406]	train-rmse:0.37567	valid-rmse:0.41914
# [407]	train-rmse:0.37554	valid-rmse:0.41912
# [408]	train-rmse:0.37543	valid-rmse:0.41911
# [409]	train-rmse:0.37538	valid-rmse:0.41911
# [410]	train-rmse:0.37536	valid-rmse:0.41911
# [411]	train-rmse:0.37518	valid-rmse:0.41908
# [412]	train-rmse:0.37510	valid-rmse:0.41906
# [413]	train-rmse:0.37509	valid-rmse:0.41905
# [414]	train-rmse:0.37508	valid-rmse:0.41905
# [415]	train-rmse:0.37508	valid-rmse:0.41906
# [416]	train-rmse:0.37497	valid-rmse:0.41907
# [417]	train-rmse:0.37495	valid-rmse:0.41906
# [418]	train-rmse:0.37491	valid-rmse:0.41905
# [419]	train-rmse:0.37489	valid-rmse:0.41906
# [420]	train-rmse:0.37473	valid-rmse:0.41904
# [421]	train-rmse:0.37465	valid-rmse:0.41897
# [422]	train-rmse:0.37451	valid-rmse:0.41898
# [423]	train-rmse:0.37439	valid-rmse:0.41896
# [424]	train-rmse:0.37424	valid-rmse:0.41894
# [425]	train-rmse:0.37409	valid-rmse:0.41889
# [426]	train-rmse:0.37398	valid-rmse:0.41888
# [427]	train-rmse:0.37394	valid-rmse:0.41886
# [428]	train-rmse:0.37376	valid-rmse:0.41886
# [429]	train-rmse:0.37366	valid-rmse:0.41884
# [430]	train-rmse:0.37342	valid-rmse:0.41880
# [431]	train-rmse:0.37323	valid-rmse:0.41877
# [432]	train-rmse:0.37313	valid-rmse:0.41878
# [433]	train-rmse:0.37296	valid-rmse:0.41879
# [434]	train-rmse:0.37284	valid-rmse:0.41877
# [435]	train-rmse:0.37261	valid-rmse:0.41876
# [436]	train-rmse:0.37253	valid-rmse:0.41872
# [437]	train-rmse:0.37248	valid-rmse:0.41872
# [438]	train-rmse:0.37247	valid-rmse:0.41871
# [439]	train-rmse:0.37247	valid-rmse:0.41871
# [440]	train-rmse:0.37241	valid-rmse:0.41873
# [441]	train-rmse:0.37237	valid-rmse:0.41874
# [442]	train-rmse:0.37236	valid-rmse:0.41875
# [443]	train-rmse:0.37215	valid-rmse:0.41870
# [444]	train-rmse:0.37201	valid-rmse:0.41868
# [445]	train-rmse:0.37185	valid-rmse:0.41866
# [446]	train-rmse:0.37172	valid-rmse:0.41859
# [447]	train-rmse:0.37155	valid-rmse:0.41859
# [448]	train-rmse:0.37136	valid-rmse:0.41859
# [449]	train-rmse:0.37130	valid-rmse:0.41859
# [450]	train-rmse:0.37128	valid-rmse:0.41858
# [451]	train-rmse:0.37119	valid-rmse:0.41856
# [452]	train-rmse:0.37114	valid-rmse:0.41856
# [453]	train-rmse:0.37095	valid-rmse:0.41857
# [454]	train-rmse:0.37094	valid-rmse:0.41857
# [455]	train-rmse:0.37072	valid-rmse:0.41850
# [456]	train-rmse:0.37051	valid-rmse:0.41844
# [457]	train-rmse:0.37034	valid-rmse:0.41837
# [458]	train-rmse:0.37024	valid-rmse:0.41837
# [459]	train-rmse:0.37013	valid-rmse:0.41838
# [460]	train-rmse:0.36998	valid-rmse:0.41837
# [461]	train-rmse:0.36984	valid-rmse:0.41840
# [462]	train-rmse:0.36968	valid-rmse:0.41838
# [463]	train-rmse:0.36959	valid-rmse:0.41837
# [464]	train-rmse:0.36946	valid-rmse:0.41836
# [465]	train-rmse:0.36929	valid-rmse:0.41835
# [466]	train-rmse:0.36926	valid-rmse:0.41833
# [467]	train-rmse:0.36920	valid-rmse:0.41834
# [468]	train-rmse:0.36907	valid-rmse:0.41835
# [469]	train-rmse:0.36897	valid-rmse:0.41833
# [470]	train-rmse:0.36896	valid-rmse:0.41833
# [471]	train-rmse:0.36895	valid-rmse:0.41832
# [472]	train-rmse:0.36894	valid-rmse:0.41831
# [473]	train-rmse:0.36889	valid-rmse:0.41831
# [474]	train-rmse:0.36886	valid-rmse:0.41830
# [475]	train-rmse:0.36886	valid-rmse:0.41830
# [476]	train-rmse:0.36880	valid-rmse:0.41829
# [477]	train-rmse:0.36876	valid-rmse:0.41831
# [478]	train-rmse:0.36859	valid-rmse:0.41833
# [479]	train-rmse:0.36852	valid-rmse:0.41833
# [480]	train-rmse:0.36838	valid-rmse:0.41829
# [481]	train-rmse:0.36831	valid-rmse:0.41827
# [482]	train-rmse:0.36826	valid-rmse:0.41825
# [483]	train-rmse:0.36808	valid-rmse:0.41822
# [484]	train-rmse:0.36807	valid-rmse:0.41822
# [485]	train-rmse:0.36783	valid-rmse:0.41813
# [486]	train-rmse:0.36776	valid-rmse:0.41812
# [487]	train-rmse:0.36758	valid-rmse:0.41808
# [488]	train-rmse:0.36743	valid-rmse:0.41807
# [489]	train-rmse:0.36734	valid-rmse:0.41805
# [490]	train-rmse:0.36732	valid-rmse:0.41804
# [491]	train-rmse:0.36729	valid-rmse:0.41805
# [492]	train-rmse:0.36724	valid-rmse:0.41805
# [493]	train-rmse:0.36723	valid-rmse:0.41804
# [494]	train-rmse:0.36723	valid-rmse:0.41803
# [495]	train-rmse:0.36722	valid-rmse:0.41803
# [496]	train-rmse:0.36721	valid-rmse:0.41803
# [497]	train-rmse:0.36721	valid-rmse:0.41804
# [498]	train-rmse:0.36719	valid-rmse:0.41803
# [499]	train-rmse:0.36712	valid-rmse:0.41801
# [500]	train-rmse:0.36704	valid-rmse:0.41798
# [501]	train-rmse:0.36702	valid-rmse:0.41798
# [502]	train-rmse:0.36702	valid-rmse:0.41798
# [503]	train-rmse:0.36698	valid-rmse:0.41796
# [504]	train-rmse:0.36675	valid-rmse:0.41790
# [505]	train-rmse:0.36657	valid-rmse:0.41785
# [506]	train-rmse:0.36640	valid-rmse:0.41785
# [507]	train-rmse:0.36623	valid-rmse:0.41783
# [508]	train-rmse:0.36609	valid-rmse:0.41779
# [509]	train-rmse:0.36601	valid-rmse:0.41777
# [510]	train-rmse:0.36586	valid-rmse:0.41774
# [511]	train-rmse:0.36570	valid-rmse:0.41769
# [512]	train-rmse:0.36565	valid-rmse:0.41768
# [513]	train-rmse:0.36560	valid-rmse:0.41769
# [514]	train-rmse:0.36559	valid-rmse:0.41770
# [515]	train-rmse:0.36538	valid-rmse:0.41763
# [516]	train-rmse:0.36521	valid-rmse:0.41758
# [517]	train-rmse:0.36504	valid-rmse:0.41753
# [518]	train-rmse:0.36487	valid-rmse:0.41747
# [519]	train-rmse:0.36468	valid-rmse:0.41744
# [520]	train-rmse:0.36453	valid-rmse:0.41741
# [521]	train-rmse:0.36441	valid-rmse:0.41740
# [522]	train-rmse:0.36430	valid-rmse:0.41740
# [523]	train-rmse:0.36409	valid-rmse:0.41735
# [524]	train-rmse:0.36393	valid-rmse:0.41731
# [525]	train-rmse:0.36383	valid-rmse:0.41734
# [526]	train-rmse:0.36367	valid-rmse:0.41732
# [527]	train-rmse:0.36367	valid-rmse:0.41733
# [528]	train-rmse:0.36353	valid-rmse:0.41729
# [529]	train-rmse:0.36333	valid-rmse:0.41722
# [530]	train-rmse:0.36332	valid-rmse:0.41723
# [531]	train-rmse:0.36329	valid-rmse:0.41724
# [532]	train-rmse:0.36326	valid-rmse:0.41724
# [533]	train-rmse:0.36307	valid-rmse:0.41727
# [534]	train-rmse:0.36295	valid-rmse:0.41723
# [535]	train-rmse:0.36286	valid-rmse:0.41720
# [536]	train-rmse:0.36276	valid-rmse:0.41722
# [537]	train-rmse:0.36264	valid-rmse:0.41722
# [538]	train-rmse:0.36256	valid-rmse:0.41722
# [539]	train-rmse:0.36246	valid-rmse:0.41720
# [540]	train-rmse:0.36234	valid-rmse:0.41720
# [541]	train-rmse:0.36214	valid-rmse:0.41716
# [542]	train-rmse:0.36205	valid-rmse:0.41716
# [543]	train-rmse:0.36198	valid-rmse:0.41715
# [544]	train-rmse:0.36197	valid-rmse:0.41715
# [545]	train-rmse:0.36196	valid-rmse:0.41715
# [546]	train-rmse:0.36195	valid-rmse:0.41714
# [547]	train-rmse:0.36178	valid-rmse:0.41712
# [548]	train-rmse:0.36160	valid-rmse:0.41706
# [549]	train-rmse:0.36145	valid-rmse:0.41706
# [550]	train-rmse:0.36130	valid-rmse:0.41704
# [551]	train-rmse:0.36122	valid-rmse:0.41706
# [552]	train-rmse:0.36113	valid-rmse:0.41705
# [553]	train-rmse:0.36105	valid-rmse:0.41702
# [554]	train-rmse:0.36086	valid-rmse:0.41696
# [555]	train-rmse:0.36077	valid-rmse:0.41697
# [556]	train-rmse:0.36054	valid-rmse:0.41687
# [557]	train-rmse:0.36031	valid-rmse:0.41683
# [558]	train-rmse:0.36012	valid-rmse:0.41679
# [559]	train-rmse:0.35996	valid-rmse:0.41677
# [560]	train-rmse:0.35991	valid-rmse:0.41676
# [561]	train-rmse:0.35971	valid-rmse:0.41674
# [562]	train-rmse:0.35962	valid-rmse:0.41675
# [563]	train-rmse:0.35940	valid-rmse:0.41666
# [564]	train-rmse:0.35927	valid-rmse:0.41663
# [565]	train-rmse:0.35919	valid-rmse:0.41663
# [566]	train-rmse:0.35899	valid-rmse:0.41664
# [567]	train-rmse:0.35891	valid-rmse:0.41664
# [568]	train-rmse:0.35882	valid-rmse:0.41662
# [569]	train-rmse:0.35876	valid-rmse:0.41661
# [570]	train-rmse:0.35858	valid-rmse:0.41664
# [571]	train-rmse:0.35847	valid-rmse:0.41662
# [572]	train-rmse:0.35837	valid-rmse:0.41662
# [573]	train-rmse:0.35819	valid-rmse:0.41657
# [574]	train-rmse:0.35800	valid-rmse:0.41657
# [575]	train-rmse:0.35791	valid-rmse:0.41657
# [576]	train-rmse:0.35786	valid-rmse:0.41658
# [577]	train-rmse:0.35785	valid-rmse:0.41658
# [578]	train-rmse:0.35770	valid-rmse:0.41659
# [579]	train-rmse:0.35762	valid-rmse:0.41659
# [580]	train-rmse:0.35761	valid-rmse:0.41659
# [581]	train-rmse:0.35738	valid-rmse:0.41656
# [582]	train-rmse:0.35729	valid-rmse:0.41653
# [583]	train-rmse:0.35719	valid-rmse:0.41655
# [584]	train-rmse:0.35715	valid-rmse:0.41654
# [585]	train-rmse:0.35707	valid-rmse:0.41655
# [586]	train-rmse:0.35707	valid-rmse:0.41655
# [587]	train-rmse:0.35694	valid-rmse:0.41654
# [588]	train-rmse:0.35680	valid-rmse:0.41649
# [589]	train-rmse:0.35670	valid-rmse:0.41646
# [590]	train-rmse:0.35667	valid-rmse:0.41647
# [591]	train-rmse:0.35667	valid-rmse:0.41646
# [592]	train-rmse:0.35646	valid-rmse:0.41645
# [593]	train-rmse:0.35642	valid-rmse:0.41645
# [594]	train-rmse:0.35632	valid-rmse:0.41642
# [595]	train-rmse:0.35629	valid-rmse:0.41643
# [596]	train-rmse:0.35614	valid-rmse:0.41644
# [597]	train-rmse:0.35601	valid-rmse:0.41646
# [598]	train-rmse:0.35593	valid-rmse:0.41646
# [599]	train-rmse:0.35575	valid-rmse:0.41642
# [600]	train-rmse:0.35572	valid-rmse:0.41642
# [601]	train-rmse:0.35567	valid-rmse:0.41641
# [602]	train-rmse:0.35561	valid-rmse:0.41641
# [603]	train-rmse:0.35550	valid-rmse:0.41640
# [604]	train-rmse:0.35532	valid-rmse:0.41633
# [605]	train-rmse:0.35518	valid-rmse:0.41633
# [606]	train-rmse:0.35499	valid-rmse:0.41631
# [607]	train-rmse:0.35483	valid-rmse:0.41628
# [608]	train-rmse:0.35465	valid-rmse:0.41625
# [609]	train-rmse:0.35444	valid-rmse:0.41626
# [610]	train-rmse:0.35431	valid-rmse:0.41623
# [611]	train-rmse:0.35414	valid-rmse:0.41624
# [612]	train-rmse:0.35397	valid-rmse:0.41621
# [613]	train-rmse:0.35388	valid-rmse:0.41620
# [614]	train-rmse:0.35383	valid-rmse:0.41620
# [615]	train-rmse:0.35381	valid-rmse:0.41620
# [616]	train-rmse:0.35376	valid-rmse:0.41620
# [617]	train-rmse:0.35373	valid-rmse:0.41619
# [618]	train-rmse:0.35365	valid-rmse:0.41619
# [619]	train-rmse:0.35342	valid-rmse:0.41618
# [620]	train-rmse:0.35337	valid-rmse:0.41617
# [621]	train-rmse:0.35324	valid-rmse:0.41618
# [622]	train-rmse:0.35318	valid-rmse:0.41617
# [623]	train-rmse:0.35307	valid-rmse:0.41617
# [624]	train-rmse:0.35307	valid-rmse:0.41617
# [625]	train-rmse:0.35306	valid-rmse:0.41617
# [626]	train-rmse:0.35297	valid-rmse:0.41613
# [627]	train-rmse:0.35279	valid-rmse:0.41609
# [628]	train-rmse:0.35268	valid-rmse:0.41611
# [629]	train-rmse:0.35253	valid-rmse:0.41609
# [630]	train-rmse:0.35243	valid-rmse:0.41611
# [631]	train-rmse:0.35221	valid-rmse:0.41611
# [632]	train-rmse:0.35213	valid-rmse:0.41609
# [633]	train-rmse:0.35206	valid-rmse:0.41609
# [634]	train-rmse:0.35197	valid-rmse:0.41606
# [635]	train-rmse:0.35190	valid-rmse:0.41605
# [636]	train-rmse:0.35185	valid-rmse:0.41605
# [637]	train-rmse:0.35184	valid-rmse:0.41604
# [638]	train-rmse:0.35174	valid-rmse:0.41605
# [639]	train-rmse:0.35166	valid-rmse:0.41605
# [640]	train-rmse:0.35163	valid-rmse:0.41605
# [641]	train-rmse:0.35163	valid-rmse:0.41605
# [642]	train-rmse:0.35149	valid-rmse:0.41601
# [643]	train-rmse:0.35144	valid-rmse:0.41601
# [644]	train-rmse:0.35139	valid-rmse:0.41600
# [645]	train-rmse:0.35138	valid-rmse:0.41600
# [646]	train-rmse:0.35137	valid-rmse:0.41599
# [647]	train-rmse:0.35131	valid-rmse:0.41598
# [648]	train-rmse:0.35112	valid-rmse:0.41596
# [649]	train-rmse:0.35099	valid-rmse:0.41595
# [650]	train-rmse:0.35089	valid-rmse:0.41593
# [651]	train-rmse:0.35081	valid-rmse:0.41593
# [652]	train-rmse:0.35071	valid-rmse:0.41596
# [653]	train-rmse:0.35062	valid-rmse:0.41595
# [654]	train-rmse:0.35044	valid-rmse:0.41588
# [655]	train-rmse:0.35032	valid-rmse:0.41587
# [656]	train-rmse:0.35016	valid-rmse:0.41584
# [657]	train-rmse:0.35003	valid-rmse:0.41581
# [658]	train-rmse:0.34991	valid-rmse:0.41581
# [659]	train-rmse:0.34990	valid-rmse:0.41581
# [660]	train-rmse:0.34980	valid-rmse:0.41581
# [661]	train-rmse:0.34972	valid-rmse:0.41580
# [662]	train-rmse:0.34971	valid-rmse:0.41580
# [663]	train-rmse:0.34950	valid-rmse:0.41576
# [664]	train-rmse:0.34943	valid-rmse:0.41574
# [665]	train-rmse:0.34940	valid-rmse:0.41575
# [666]	train-rmse:0.34926	valid-rmse:0.41574
# [667]	train-rmse:0.34909	valid-rmse:0.41573
# [668]	train-rmse:0.34893	valid-rmse:0.41571
# [669]	train-rmse:0.34876	valid-rmse:0.41569
# [670]	train-rmse:0.34862	valid-rmse:0.41567
# [671]	train-rmse:0.34855	valid-rmse:0.41567
# [672]	train-rmse:0.34844	valid-rmse:0.41566
# [673]	train-rmse:0.34823	valid-rmse:0.41562
# [674]	train-rmse:0.34821	valid-rmse:0.41561
# [675]	train-rmse:0.34805	valid-rmse:0.41560
# [676]	train-rmse:0.34797	valid-rmse:0.41559
# [677]	train-rmse:0.34793	valid-rmse:0.41558
# [678]	train-rmse:0.34789	valid-rmse:0.41559
# [679]	train-rmse:0.34789	valid-rmse:0.41558
# [680]	train-rmse:0.34789	valid-rmse:0.41558
# [681]	train-rmse:0.34786	valid-rmse:0.41558
# [682]	train-rmse:0.34785	valid-rmse:0.41558
# [683]	train-rmse:0.34771	valid-rmse:0.41557
# [684]	train-rmse:0.34760	valid-rmse:0.41559
# [685]	train-rmse:0.34755	valid-rmse:0.41558
# [686]	train-rmse:0.34748	valid-rmse:0.41559
# [687]	train-rmse:0.34738	valid-rmse:0.41557
# [688]	train-rmse:0.34737	valid-rmse:0.41557
# [689]	train-rmse:0.34737	valid-rmse:0.41557
# [690]	train-rmse:0.34732	valid-rmse:0.41557
# [691]	train-rmse:0.34726	valid-rmse:0.41555
# [692]	train-rmse:0.34712	valid-rmse:0.41553
# [693]	train-rmse:0.34694	valid-rmse:0.41554
# [694]	train-rmse:0.34681	valid-rmse:0.41557
# [695]	train-rmse:0.34665	valid-rmse:0.41553
# [696]	train-rmse:0.34658	valid-rmse:0.41553
# [697]	train-rmse:0.34647	valid-rmse:0.41556
# [698]	train-rmse:0.34645	valid-rmse:0.41555
# [699]	train-rmse:0.34645	valid-rmse:0.41556
# [700]	train-rmse:0.34636	valid-rmse:0.41554
# [701]	train-rmse:0.34626	valid-rmse:0.41552
# [702]	train-rmse:0.34625	valid-rmse:0.41552
# [703]	train-rmse:0.34624	valid-rmse:0.41553
# [704]	train-rmse:0.34616	valid-rmse:0.41552
# [705]	train-rmse:0.34616	valid-rmse:0.41552
# [706]	train-rmse:0.34614	valid-rmse:0.41551
# [707]	train-rmse:0.34603	valid-rmse:0.41552
# [708]	train-rmse:0.34600	valid-rmse:0.41552
# [709]	train-rmse:0.34599	valid-rmse:0.41552
# [710]	train-rmse:0.34595	valid-rmse:0.41552
# [711]	train-rmse:0.34577	valid-rmse:0.41550
# [712]	train-rmse:0.34576	valid-rmse:0.41550
# [713]	train-rmse:0.34564	valid-rmse:0.41547
# [714]	train-rmse:0.34553	valid-rmse:0.41547
# [715]	train-rmse:0.34552	valid-rmse:0.41547
# [716]	train-rmse:0.34548	valid-rmse:0.41547
# [717]	train-rmse:0.34546	valid-rmse:0.41547
# [718]	train-rmse:0.34543	valid-rmse:0.41546
# [719]	train-rmse:0.34543	valid-rmse:0.41546
# [720]	train-rmse:0.34542	valid-rmse:0.41545
# [721]	train-rmse:0.34541	valid-rmse:0.41545
# [722]	train-rmse:0.34539	valid-rmse:0.41546
# [723]	train-rmse:0.34525	valid-rmse:0.41545
# [724]	train-rmse:0.34512	valid-rmse:0.41546
# [725]	train-rmse:0.34492	valid-rmse:0.41541
# [726]	train-rmse:0.34480	valid-rmse:0.41541
# [727]	train-rmse:0.34466	valid-rmse:0.41538
# [728]	train-rmse:0.34451	valid-rmse:0.41537
# [729]	train-rmse:0.34437	valid-rmse:0.41533
# [730]	train-rmse:0.34421	valid-rmse:0.41532
# [731]	train-rmse:0.34411	valid-rmse:0.41528
# [732]	train-rmse:0.34399	valid-rmse:0.41527
# [733]	train-rmse:0.34383	valid-rmse:0.41525
# [734]	train-rmse:0.34373	valid-rmse:0.41525
# [735]	train-rmse:0.34362	valid-rmse:0.41526
# [736]	train-rmse:0.34355	valid-rmse:0.41527
# [737]	train-rmse:0.34336	valid-rmse:0.41522
# [738]	train-rmse:0.34335	valid-rmse:0.41523
# [739]	train-rmse:0.34333	valid-rmse:0.41522
# [740]	train-rmse:0.34332	valid-rmse:0.41522
# [741]	train-rmse:0.34322	valid-rmse:0.41527
# [742]	train-rmse:0.34321	valid-rmse:0.41526
# [743]	train-rmse:0.34307	valid-rmse:0.41525
# [744]	train-rmse:0.34297	valid-rmse:0.41524
# [745]	train-rmse:0.34277	valid-rmse:0.41519
# [746]	train-rmse:0.34257	valid-rmse:0.41512
# [747]	train-rmse:0.34239	valid-rmse:0.41509
# [748]	train-rmse:0.34229	valid-rmse:0.41506
# [749]	train-rmse:0.34227	valid-rmse:0.41507
# [750]	train-rmse:0.34223	valid-rmse:0.41508
# [751]	train-rmse:0.34221	valid-rmse:0.41508
# [752]	train-rmse:0.34214	valid-rmse:0.41506
# [753]	train-rmse:0.34212	valid-rmse:0.41505
# [754]	train-rmse:0.34194	valid-rmse:0.41499
# [755]	train-rmse:0.34187	valid-rmse:0.41500
# [756]	train-rmse:0.34180	valid-rmse:0.41499
# [757]	train-rmse:0.34163	valid-rmse:0.41497
# [758]	train-rmse:0.34147	valid-rmse:0.41495
# [759]	train-rmse:0.34127	valid-rmse:0.41492
# [760]	train-rmse:0.34113	valid-rmse:0.41490
# [761]	train-rmse:0.34104	valid-rmse:0.41489
# [762]	train-rmse:0.34101	valid-rmse:0.41490
# [763]	train-rmse:0.34098	valid-rmse:0.41487
# [764]	train-rmse:0.34083	valid-rmse:0.41485
# [765]	train-rmse:0.34066	valid-rmse:0.41483
# [766]	train-rmse:0.34052	valid-rmse:0.41477
# [767]	train-rmse:0.34044	valid-rmse:0.41475
# [768]	train-rmse:0.34039	valid-rmse:0.41476
# [769]	train-rmse:0.34030	valid-rmse:0.41474
# [770]	train-rmse:0.34022	valid-rmse:0.41471
# [771]	train-rmse:0.34005	valid-rmse:0.41470
# [772]	train-rmse:0.33994	valid-rmse:0.41470
# [773]	train-rmse:0.33992	valid-rmse:0.41471
# [774]	train-rmse:0.33988	valid-rmse:0.41473
# [775]	train-rmse:0.33974	valid-rmse:0.41475
# [776]	train-rmse:0.33960	valid-rmse:0.41475
# [777]	train-rmse:0.33948	valid-rmse:0.41471
# [778]	train-rmse:0.33943	valid-rmse:0.41471
# [779]	train-rmse:0.33931	valid-rmse:0.41468
# [780]	train-rmse:0.33921	valid-rmse:0.41467
# [781]	train-rmse:0.33911	valid-rmse:0.41465
# [782]	train-rmse:0.33908	valid-rmse:0.41466
# [783]	train-rmse:0.33907	valid-rmse:0.41466
# [784]	train-rmse:0.33904	valid-rmse:0.41466
# [785]	train-rmse:0.33904	valid-rmse:0.41465
# [786]	train-rmse:0.33903	valid-rmse:0.41465
# [787]	train-rmse:0.33897	valid-rmse:0.41463
# [788]	train-rmse:0.33890	valid-rmse:0.41466
# [789]	train-rmse:0.33883	valid-rmse:0.41467
# [790]	train-rmse:0.33879	valid-rmse:0.41467
# [791]	train-rmse:0.33873	valid-rmse:0.41467
# [792]	train-rmse:0.33856	valid-rmse:0.41465
# [793]	train-rmse:0.33848	valid-rmse:0.41464
# [794]	train-rmse:0.33838	valid-rmse:0.41463
# [795]	train-rmse:0.33831	valid-rmse:0.41459
# [796]	train-rmse:0.33824	valid-rmse:0.41458
# [797]	train-rmse:0.33814	valid-rmse:0.41456
# [798]	train-rmse:0.33803	valid-rmse:0.41454
# [799]	train-rmse:0.33796	valid-rmse:0.41451
# [800]	train-rmse:0.33794	valid-rmse:0.41451
# [801]	train-rmse:0.33791	valid-rmse:0.41452
# [802]	train-rmse:0.33775	valid-rmse:0.41453
# [803]	train-rmse:0.33772	valid-rmse:0.41452
# [804]	train-rmse:0.33758	valid-rmse:0.41452
# [805]	train-rmse:0.33757	valid-rmse:0.41452
# [806]	train-rmse:0.33748	valid-rmse:0.41449
# [807]	train-rmse:0.33741	valid-rmse:0.41449
# [808]	train-rmse:0.33737	valid-rmse:0.41450
# [809]	train-rmse:0.33733	valid-rmse:0.41449
# [810]	train-rmse:0.33731	valid-rmse:0.41448
# [811]	train-rmse:0.33730	valid-rmse:0.41449
# [812]	train-rmse:0.33716	valid-rmse:0.41448
# [813]	train-rmse:0.33710	valid-rmse:0.41450
# [814]	train-rmse:0.33701	valid-rmse:0.41451
# [815]	train-rmse:0.33690	valid-rmse:0.41450
# [816]	train-rmse:0.33676	valid-rmse:0.41450
# [817]	train-rmse:0.33670	valid-rmse:0.41450
# [818]	train-rmse:0.33656	valid-rmse:0.41449
# [819]	train-rmse:0.33653	valid-rmse:0.41448
# [820]	train-rmse:0.33643	valid-rmse:0.41448
# [821]	train-rmse:0.33635	valid-rmse:0.41447
# [822]	train-rmse:0.33622	valid-rmse:0.41445
# [823]	train-rmse:0.33622	valid-rmse:0.41445
# [824]	train-rmse:0.33618	valid-rmse:0.41444
# [825]	train-rmse:0.33611	valid-rmse:0.41445
# [826]	train-rmse:0.33601	valid-rmse:0.41445
# [827]	train-rmse:0.33592	valid-rmse:0.41441
# [828]	train-rmse:0.33590	valid-rmse:0.41439
# [829]	train-rmse:0.33587	valid-rmse:0.41438
# [830]	train-rmse:0.33586	valid-rmse:0.41438
# [831]	train-rmse:0.33584	valid-rmse:0.41438
# [832]	train-rmse:0.33580	valid-rmse:0.41436
# [833]	train-rmse:0.33565	valid-rmse:0.41434
# [834]	train-rmse:0.33547	valid-rmse:0.41433
# [835]	train-rmse:0.33532	valid-rmse:0.41431
# [836]	train-rmse:0.33519	valid-rmse:0.41429
# [837]	train-rmse:0.33516	valid-rmse:0.41429
# [838]	train-rmse:0.33510	valid-rmse:0.41427
# [839]	train-rmse:0.33495	valid-rmse:0.41429
# [840]	train-rmse:0.33480	valid-rmse:0.41428
# [841]	train-rmse:0.33468	valid-rmse:0.41430
# [842]	train-rmse:0.33460	valid-rmse:0.41428
# [843]	train-rmse:0.33453	valid-rmse:0.41426
# [844]	train-rmse:0.33450	valid-rmse:0.41426
# [845]	train-rmse:0.33437	valid-rmse:0.41426
# [846]	train-rmse:0.33422	valid-rmse:0.41425
# [847]	train-rmse:0.33405	valid-rmse:0.41422
# [848]	train-rmse:0.33398	valid-rmse:0.41422
# [849]	train-rmse:0.33397	valid-rmse:0.41422
# [850]	train-rmse:0.33393	valid-rmse:0.41422
# [851]	train-rmse:0.33385	valid-rmse:0.41423
# [852]	train-rmse:0.33383	valid-rmse:0.41421
# [853]	train-rmse:0.33372	valid-rmse:0.41423
# [854]	train-rmse:0.33362	valid-rmse:0.41424
# [855]	train-rmse:0.33345	valid-rmse:0.41424
# [856]	train-rmse:0.33344	valid-rmse:0.41424
# [857]	train-rmse:0.33338	valid-rmse:0.41426
# [858]	train-rmse:0.33326	valid-rmse:0.41423
# [859]	train-rmse:0.33319	valid-rmse:0.41424
# [860]	train-rmse:0.33313	valid-rmse:0.41421
# [861]	train-rmse:0.33299	valid-rmse:0.41420
# [862]	train-rmse:0.33297	valid-rmse:0.41419
# [863]	train-rmse:0.33296	valid-rmse:0.41419
# [864]	train-rmse:0.33295	valid-rmse:0.41420
# [865]	train-rmse:0.33294	valid-rmse:0.41419
# [866]	train-rmse:0.33277	valid-rmse:0.41417
# [867]	train-rmse:0.33264	valid-rmse:0.41417
# [868]	train-rmse:0.33246	valid-rmse:0.41413
# [869]	train-rmse:0.33235	valid-rmse:0.41413
# [870]	train-rmse:0.33224	valid-rmse:0.41411
# [871]	train-rmse:0.33220	valid-rmse:0.41409
# [872]	train-rmse:0.33217	valid-rmse:0.41407
# [873]	train-rmse:0.33212	valid-rmse:0.41408
# [874]	train-rmse:0.33210	valid-rmse:0.41408
# [875]	train-rmse:0.33207	valid-rmse:0.41407
# [876]	train-rmse:0.33192	valid-rmse:0.41406
# [877]	train-rmse:0.33174	valid-rmse:0.41405
# [878]	train-rmse:0.33168	valid-rmse:0.41403
# [879]	train-rmse:0.33158	valid-rmse:0.41399
# [880]	train-rmse:0.33141	valid-rmse:0.41397
# [881]	train-rmse:0.33127	valid-rmse:0.41397
# [882]	train-rmse:0.33120	valid-rmse:0.41396
# [883]	train-rmse:0.33109	valid-rmse:0.41395
# [884]	train-rmse:0.33096	valid-rmse:0.41392
# [885]	train-rmse:0.33091	valid-rmse:0.41395
# [886]	train-rmse:0.33086	valid-rmse:0.41393
# [887]	train-rmse:0.33081	valid-rmse:0.41393
# [888]	train-rmse:0.33069	valid-rmse:0.41395
# [889]	train-rmse:0.33051	valid-rmse:0.41395
# [890]	train-rmse:0.33039	valid-rmse:0.41393
# [891]	train-rmse:0.33032	valid-rmse:0.41392
# [892]	train-rmse:0.33027	valid-rmse:0.41393
# [893]	train-rmse:0.33015	valid-rmse:0.41390
# [894]	train-rmse:0.33012	valid-rmse:0.41391
# [895]	train-rmse:0.33003	valid-rmse:0.41389
# [896]	train-rmse:0.32991	valid-rmse:0.41390
# [897]	train-rmse:0.32985	valid-rmse:0.41392
# [898]	train-rmse:0.32982	valid-rmse:0.41391
# [899]	train-rmse:0.32970	valid-rmse:0.41387
# [900]	train-rmse:0.32959	valid-rmse:0.41385
# [901]	train-rmse:0.32951	valid-rmse:0.41385
# [902]	train-rmse:0.32947	valid-rmse:0.41384
# [903]	train-rmse:0.32946	valid-rmse:0.41385
# [904]	train-rmse:0.32941	valid-rmse:0.41384
# [905]	train-rmse:0.32937	valid-rmse:0.41384
# [906]	train-rmse:0.32936	valid-rmse:0.41384
# [907]	train-rmse:0.32935	valid-rmse:0.41384
# [908]	train-rmse:0.32929	valid-rmse:0.41381
# [909]	train-rmse:0.32918	valid-rmse:0.41381
# [910]	train-rmse:0.32916	valid-rmse:0.41382
# [911]	train-rmse:0.32916	valid-rmse:0.41382
# [912]	train-rmse:0.32915	valid-rmse:0.41382
# [913]	train-rmse:0.32899	valid-rmse:0.41378
# [914]	train-rmse:0.32888	valid-rmse:0.41374
# [915]	train-rmse:0.32876	valid-rmse:0.41376
# [916]	train-rmse:0.32871	valid-rmse:0.41376
# [917]	train-rmse:0.32863	valid-rmse:0.41374
# [918]	train-rmse:0.32855	valid-rmse:0.41371
# [919]	train-rmse:0.32847	valid-rmse:0.41372
# [920]	train-rmse:0.32834	valid-rmse:0.41372
# [921]	train-rmse:0.32826	valid-rmse:0.41374
# [922]	train-rmse:0.32808	valid-rmse:0.41370
# [923]	train-rmse:0.32800	valid-rmse:0.41369
# [924]	train-rmse:0.32783	valid-rmse:0.41368
# [925]	train-rmse:0.32775	valid-rmse:0.41369
# [926]	train-rmse:0.32772	valid-rmse:0.41369
# [927]	train-rmse:0.32770	valid-rmse:0.41369
# [928]	train-rmse:0.32768	valid-rmse:0.41369
# [929]	train-rmse:0.32761	valid-rmse:0.41366
# [930]	train-rmse:0.32760	valid-rmse:0.41366
# [931]	train-rmse:0.32760	valid-rmse:0.41365
# [932]	train-rmse:0.32759	valid-rmse:0.41365
# [933]	train-rmse:0.32754	valid-rmse:0.41364
# [934]	train-rmse:0.32754	valid-rmse:0.41364
# [935]	train-rmse:0.32747	valid-rmse:0.41363
# [936]	train-rmse:0.32741	valid-rmse:0.41365
# [937]	train-rmse:0.32732	valid-rmse:0.41369
# [938]	train-rmse:0.32715	valid-rmse:0.41369
# [939]	train-rmse:0.32703	valid-rmse:0.41370
# [940]	train-rmse:0.32694	valid-rmse:0.41371
# [941]	train-rmse:0.32682	valid-rmse:0.41367
# [942]	train-rmse:0.32678	valid-rmse:0.41368
# [943]	train-rmse:0.32669	valid-rmse:0.41368
# [944]	train-rmse:0.32656	valid-rmse:0.41371
# [945]	train-rmse:0.32645	valid-rmse:0.41370

# %% [markdown]
# 우선 모델을 만들고 학습하기 위해 몇 가지 선택해야 하는 옵션은 **딕셔너리를 만들어 넣으면 됨**
# 이때 이 딕셔너리에는 모델의 목적함수와 평가 지표를 정해서 넣어야 함.
# 여기서는 우선 목적함수의 경우 **이진 로지스틱 함수** 사용
# 평가 지표의 경우 **rmse(Root mean squared error)** 사용
# 이렇게 만든 인자와 학습 데이터, 데이터를 반복하는 횟수인 num_boost_round, 모델 검증 시 사용할 전체 데이터 쌍, 그리고 early stopping을 위한 횟수를 지정.
#
# 데이터 반복 횟수, 즉 epoch을 의미하는 값으로는 1000 설정.
# 이는 전체 데이터를 만번 반복해야 끝나도록 설정한 것.
# 또한 early stopping을 위한 횟수값으로 10을 설정했는데 이는 만약 10 epoch 동안 에러값이 별로 줄어들지 않았을 경우에는 학습을 early stopping하게 하는 것.

# %% [markdown]
# 위에 학습 과정을 보면 각 step마다 학습 에러와 검증 에러를 계속 보여주고 있으며, 945 스텝에서 학습이 끝났다.
#
# 이제 만든 모델을 사용해 평가 데이터를 예측하고 예측 결과를 kaggle에 제출할 수 있게 파일로 만들어보자.

# %%
TEST_Q1_DATA_FILE = 'test_q1.npy'
TEST_Q2_DATA_FILE = 'test_q2.npy'
TEST_ID_DATA_FILE = 'test_id.npy'

test_q1_data = np.load(open(DATA_IN_PATH + TEST_Q1_DATA_FILE, 'rb'))
test_q2_data = np.load(open(DATA_IN_PATH + TEST_Q2_DATA_FILE, 'rb'))
#test_id_data = np.load(open(DATA_IN_PATH + TEST_ID_DATA_FILE, 'rb'))

# %%
test_input = np.stack((test_q1_data, test_q2_data), axis = 1)
test_data = xgb.DMatrix(test_input.sum(axis = 1))

test_predict = bst.predict(test_data)

# %%
import os
DATA_OUT_PATH = './data_out/'

if not os.path.exists(DATA_OUT_PATH) :
    os.makedirs(DATA_OUT_PATH)
    
output = pd.DataFrame({'test_id': test_id, 'is_duplicate': test_predict})
output.to_csv(DATA_OUT_PATH + 'simple_xgb.csv', index = False)
